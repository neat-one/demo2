# %%
import pandas as pd
import numpy as np
import os
import glob
import random
from PIL import Image

# %%
random.seed(151)

# %%
current_path = os.getcwd()
current_path
# Out:
# '/Users/neatone/Library/CloudStorage/OneDrive-MichiganStateUniversity/Documents/Research/Other Studies/Pokemon Study'

# %%
animal_pics = r"/Users/neatone/Library/CloudStorage/OneDrive-MichiganStateUniversity/Documents/Research/Other Studies/Pokemon Study/animals/animals (2)/animal_pics"
animal_sounds = r"/Users/neatone/Library/CloudStorage/OneDrive-MichiganStateUniversity/Documents/Research/Other Studies/Pokemon Study/animals/animal_sounds"

# %%
num = 1
fnames = os.listdir(animal_pics)

for fname in fnames:
    if fname == '.DS_Store':
        pass
    else:
        new_dir = fr"{animal_pics}/{fname}"
        for file in os.listdir(new_dir):
            orig_name = fr"{new_dir}/{file}"
            new_name = fr"{new_dir}/{fname}_{num}.jpg"
            os.rename(orig_name, new_name)
            num+=1
    num=1

# %%
num = 1
fnames = os.listdir(animal_sounds)

for fname in fnames:
    if (fname == '.DS_Store'):
        pass
    else:
        new_dir = fr"{animal_sounds}/{fname}"
        for file in os.listdir(new_dir):
            if fname == 'original sounds':
                orig_name = fr"{new_dir}/{file}"
                # find the last . and slice for the file type
                file_type = orig_name[orig_name.rfind(".") + 1:]
                new_name = fr"{new_dir}/{fname}_{num}.{file_type}"
                os.rename(orig_name, new_name)
                num+=1
    num=1

# %%
list1 = [x+1 for x in range(151)]

# %%
random.shuffle(list1)

# %%
# list1 = [28,
#  56,
#  106,
#  90,
#  89,
#  95,
#  124,
#  88,
#  5,
#  117,
#  82,
#  143,
#  104,
#  127,
#  60,
#  19,
#  135,
#  78,
#  53,
#  84,
#  87,
#  128,
#  45,
#  120,
#  71,
#  81,
#  141,
#  144,
#  93,
#  100,
#  103,
#  142,
#  97,
#  79,
#  20,
#  63,
#  65,
#  134,
#  115,
#  94,
#  51,
#  98,
#  125,
#  36,
#  96,
#  67,
#  13,
#  11,
#  21,
#  118,
#  12,
#  26,
#  110,
#  43,
#  91,
#  140,
#  35,
#  61,
#  99,
#  32,
#  126,
#  40,
#  114,
#  132,
#  85,
#  59,
#  122,
#  16,
#  147,
#  129,
#  72,
#  123,
#  37,
#  7,
#  49,
#  9,
#  137,
#  75,
#  102,
#  66,
#  50,
#  146,
#  136,
#  113,
#  2,
#  108,
#  151,
#  131,
#  119,
#  34,
#  22,
#  133,
#  76,
#  17,
#  48,
#  105,
#  46,
#  58,
#  109,
#  14,
#  41,
#  70,
#  145,
#  18,
#  55,
#  68,
#  23,
#  111,
#  107,
#  69,
#  29,
#  62,
#  77,
#  130,
#  73,
#  38,
#  101,
#  74,
#  92,
#  27,
#  112,
#  31,
#  121,
#  148,
#  139,
#  54,
#  42,
#  149,
#  24,
#  1,
#  44,
#  86,
#  33,
#  6,
#  150,
#  80,
#  39,
#  3,
#  30,
#  8,
#  10,
#  4,
#  83,
#  52,
#  116,
#  25,
#  47,
#  138,
#  57,
#  64,
#  15]

# %%
pokemon_dictionary = {
    1:'bulbasaur',
    2:'ivysaur',
    3:'venusaur',
    4:'charmander',
    5:'charmeleon',
    6:'charizard',
    7:'squirtle',
    8:'wartortle',
    9:'blastoise',
    10:'caterpie',
    11:'metapod',
    12:'butterfree',
    13:'weedle',
    14:'kakuna',
    15:'beedrill',
    16:'pidgey',
    17:'pidgeotto',
    18:'pidgeot',
    19:'rattata',
    20:'raticate',
    21:'spearow',
    22:'fearow',
    23:'ekans',
    24:'arbok',
    25:'pikachu',
    26:'raichu',
    27:'sandshrew',
    28:'sandslash',
    29:'nidoran',
    30:'nidorina',
    31:'nidoqueen',
    32:'nidoran',
    33:'nidorino',
    34:'nidoking',
    35:'clefairy',
    36:'clefable',
    37:'vulpix',
    38:'ninetales',
    39:'jigglypuff',
    40:'wigglytuff',
    41:'zubat',
    42:'golbat',
    43:'oddish',
    44:'gloom',
    45:'vileplum',
    46:'paras',
    47:'parasect',
    48:'venonat',
    49:'venomoth',
    50:'diglett',
    51:'dugtrio',
    52:'meowth',
    53:'persian',
    54:'psyduck',
    55:'golduck',
    56:'mankey',
    57:'primeape',
    58:'growlithe',
    59:'arcanine',
    60:'poliwag',
    61:'poliwhirl',
    62:'poliwrath',
    63:'abra',
    64:'kadabra',
    65:'alakazam',
    66:'machop',
    67:'machoke',
    68:'machamp',
    69:'bellsprout',
    70:'weepinbell',
    71:'victreebel',
    72:'tentacool',
    73:'tentacruel',
    74:'geodude',
    75:'graveler',
    76:'golem',
    77:'ponyta',
    78:'rapidash',
    79:'slowpoke',
    80:'slowbro',
    81:'magnemite',
    82:'magneton',
    83:"farfetch'd",
    84:'doduo',
    85:'dodrio',
    86:'seel',
    87:'dewgong',
    88:'grimer',
    89:'muk',
    90:'shellder',
    91:'cloyster',
    92:'gastly',
    93:'haunter',
    94:'gengar',
    95:'onix',
    96:'drowzee',
    97:"hypno",
    98:"krabby",
    99:"kingler",
    100:'voltorb',
    101:'electrode',
    102:'exeggcute',
    103:'exeggutor',
    104:'cubone',
    105:'marowak',
    106:'hitmonlee',
    107:'hitmonchan',
    108:'lickitung',
    109:'koffing',
    110:'weezing',
    111:'rhyhorn',
    112:'rhydon',
    113:'chansey',
    114:'tangela',
    115:'kangaskhan',
    116:'horsea',
    117:'seadra',
    118:'goldeen',
    119:'seaking',
    120:'staryu',
    121:'starmie',
    122:'mr. mime',
    123:'scyther',
    124:'jynx',
    125:'electabuzz',
    126:'magmar',
    127:'pinsir',
    128:'tauros',
    129:'magikarp',
    130:'gyarados',
    131:'lapras',
    132:'ditto',
    133:'eevee',
    134:'vaporeon',
    135:'jolteon',
    136:'flareon',
    137:'porygon',
    138:'omanyte',
    139:'omastar',
    140:'kabuto',
    141:'kabutops',
    142:'aerodactyl',
    143:'snorlax',
    144:'articuno',
    145:'zapdos',
    146:'moltres',
    147:'dratini',
    148:'dragonair',
    149:'dragonite',
    150:'mewtwo',
    151:'mew'
}

# %%
for pokemon in list1:
    ans_options = [pokemon]
    ans_options += random.choices(list1, k=5)
    while len(ans_options) != len(set(ans_options)):
        ans_options = list(set(ans_options)) + random.choices(list1, k=1)
    random.shuffle(ans_options)
    print(pokemon)
    print([pokemon_dictionary[name] for name in ans_options])
# Out:
# 131
# ['lapras', 'zapdos', 'pinsir', 'diglett', 'sandshrew', 'flareon']
# 12
# ['nidorina', 'hypno', 'voltorb', 'bellsprout', 'butterfree', 'pidgey']
# 136
# ['flareon', 'pinsir', 'starmie', 'exeggcute', 'victreebel', 'dewgong']
# 34
# ['poliwhirl', 'nidoking', 'weepinbell', 'ivysaur', 'victreebel', 'charmander']
# 11
# ['ninetales', 'charmeleon', 'nidoran', 'beedrill', 'metapod', 'machop']
# 143
# ['mewtwo', 'hitmonchan', 'snorlax', 'charmeleon', 'jolteon', 'dratini']
# 93
# ['mr. mime', 'haunter', 'zapdos', 'pidgeotto', 'doduo', 'muk']
# 137
# ['dugtrio', 'staryu', 'voltorb', 'magneton', 'porygon', 'blastoise']
# 149
# ['ekans', 'jigglypuff', 'dragonite', 'dratini', 'charizard', 'omastar']
# 42
# ['porygon', 'clefairy', 'dragonite', 'grimer', 'golbat', 'blastoise']
# 85
# ['marowak', 'tauros', 'jynx', 'electabuzz', 'dodrio', 'tentacool']
# 4
# ['koffing', 'charmander', 'vaporeon', 'gloom', 'bulbasaur', 'ditto']
# 13
# ['eevee', 'metapod', 'seadra', 'kakuna', 'bulbasaur', 'weedle']
# ...

# %%
list1 = [x+1 for x in range(151)]
random.shuffle(list1)

# %%
for pokemon in list1:
    ans_options = [pokemon]
    ans_options += random.choices(list1, k=5)
    while len(ans_options) != len(set(ans_options)):
        ans_options = list(set(ans_options)) + random.choices(list1, k=1)
    random.shuffle(ans_options)
    print(pokemon)
    print([pokemon_dictionary[name] for name in ans_options])
# Out:
# 142
# ['rhyhorn', 'primeape', 'seadra', 'vulpix', 'aerodactyl', 'blastoise']
# 28
# ['jolteon', 'shellder', 'mr. mime', 'sandslash', 'ivysaur', 'goldeen']
# 106
# ['beedrill', 'onix', 'machoke', 'hitmonlee', 'clefable', 'scyther']
# 146
# ['omastar', 'cloyster', 'moltres', 'magikarp', 'primeape', 'golbat']
# 97
# ['seaking', 'squirtle', 'pidgeotto', 'hypno', 'jynx', 'slowpoke']
# 41
# ['shellder', 'ponyta', 'metapod', 'tauros', 'machamp', 'zubat']
# 62
# ['weepinbell', 'electabuzz', 'weezing', 'poliwrath', 'rhyhorn', 'caterpie']
# 30
# ['oddish', 'nidorina', 'cubone', 'electabuzz', 'poliwhirl', 'metapod']
# 103
# ['exeggcute', 'dugtrio', 'exeggutor', 'weepinbell', 'pidgeot', 'goldeen']
# 92
# ['electabuzz', 'graveler', 'omanyte', 'slowbro', 'diglett', 'gastly']
# 46
# ['persian', 'paras', 'jynx', 'chansey', 'spearow', 'rapidash']
# 144
# ['dragonair', 'snorlax', 'electrode', 'articuno', 'charmeleon', 'alakazam']
# 63
# ...

# %%
import os
animal_pics = r"/Users/neatone/Library/CloudStorage/OneDrive-MichiganStateUniversity/Documents/Research/Other Studies/Pokemon Study/animals/animals (2)/animal_pics"
animal_sounds = r"/Users/neatone/Library/CloudStorage/OneDrive-MichiganStateUniversity/Documents/Research/Other Studies/Pokemon Study/animals/animal_sounds"
animal_types = []
fnames = os.listdir(animal_pics)

for animal in fnames:
    if animal == '.DS_Store':
        pass
    elif animal in animal_types:
        pass
    else:
        animal_types.append(animal)

# %%
# for trial in range(151):
#     print(random.choices(animal_types, k=5))

# %%
animal_types
# Out:
# ['cat',
#  'donkey',
#  'pig',
#  'dog',
#  'bee',
#  'turkey',
#  'bear',
#  'cricket',
#  'sheep',
#  'duck',
#  'owl',
#  'tiger',
#  'hyena',
#  'chicken',
#  'monkey',
#  'birds',
#  'frog',
#  'horse',
#  'cow',
#  'lion',
#  'elephant']

# %%
num = 1
fnames = os.listdir(animal_pics)
animal_dictionary = {}

for fname in fnames:
    print(fname)
    if fname == '.DS_Store':
        pass
    else:
        new_dir = fr"{animal_pics}/{fname}"
        print(new_dir)
        for file in os.listdir(new_dir):
            orig_name = fr"{new_dir}/{file}"
#             print(file)
            new_animal_choices = random.sample(animal_types, 5) + [file[:-6]]
            while len(new_animal_choices) != len(set(new_animal_choices)):
                new_animal_choices = list(set(new_animal_choices)) + random.choices(animal_types, k=1)
                random.shuffle(new_animal_choices)
            random.shuffle(new_animal_choices)
            animal_dictionary[file] = new_animal_choices

            num+=1
            
print(num)
# Out:
# cat
# /Users/neatone/Library/CloudStorage/OneDrive-MichiganStateUniversity/Documents/Research/Other Studies/Pokemon Study/animals/animals (2)/animal_pics/cat
# donkey
# /Users/neatone/Library/CloudStorage/OneDrive-MichiganStateUniversity/Documents/Research/Other Studies/Pokemon Study/animals/animals (2)/animal_pics/donkey
# pig
# /Users/neatone/Library/CloudStorage/OneDrive-MichiganStateUniversity/Documents/Research/Other Studies/Pokemon Study/animals/animals (2)/animal_pics/pig
# .DS_Store
# dog
# /Users/neatone/Library/CloudStorage/OneDrive-MichiganStateUniversity/Documents/Research/Other Studies/Pokemon Study/animals/animals (2)/animal_pics/dog
# bee
# /Users/neatone/Library/CloudStorage/OneDrive-MichiganStateUniversity/Documents/Research/Other Studies/Pokemon Study/animals/animals (2)/animal_pics/bee
# turkey
# /Users/neatone/Library/CloudStorage/OneDrive-MichiganStateUniversity/Documents/Research/Other Studies/Pokemon Study/animals/animals (2)/animal_pics/turkey
# bear
# ...

# %%
keys_ =  list(animal_dictionary.keys())
random.shuffle(keys_)

# %%
count = 0
for item in [(key, animal_dictionary[key]) for key in keys_]:
    if item[0] not in original_animal_dictionary.keys():
        print(item[0])
        random.shuffle(item[1])
        print(item[1])
        count += 1
print(count)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [19], in <cell line: 2>()
#       1 count = 0
#       2 for item in [(key, animal_dictionary[key]) for key in keys_]:
# ----> 3     if item[0] not in original_animal_dictionary.keys():
#       4         print(item[0])
#       5         random.shuffle(item[1])
#
# NameError: name 'original_animal_dictionary' is not defined

# %%
len(animal_dictionary)

# %%
original_animal_dictionary = animal_dictionary.copy()

# %%
num = 1
fnames = os.listdir(animal_sounds)
animal_dictionary = {}

for fname in fnames:
    if fname == '.DS_Store':
        pass
    else:
        new_dir = fr"{animal_sounds}/{fname}"
#         print(new_dir)
        for file in os.listdir(new_dir):
            if file == 'original sounds':
                pass
            else:
                orig_name = fr"{new_dir}/{file}"
#                 print(file)
                new_animal_choices = random.sample(animal_types, 5) + [file[:-6]]
                while len(new_animal_choices) != len(set(new_animal_choices)):
                    new_animal_choices = list(set(new_animal_choices)) + random.choices(animal_types, k=1)
                    random.shuffle(new_animal_choices)
                random.shuffle(new_animal_choices)
                animal_dictionary[file] = new_animal_choices

                num+=1
            
print(num)

# %%
keys_ =  list(animal_dictionary.keys())
random.shuffle(keys_)

# %%
count = 1
for item in [(key, animal_dictionary[key]) for key in keys_]:
    print(item[0])
    random.shuffle(item[1])
    print(item[1])
    count += 1
print(count)

# %%
num = 1
fnames = os.listdir(animal_pics)

for fname in fnames:
    if fname == '.DS_Store':
        pass
    else:
        new_dir = fr"{animal_pics}/{fname}"
        for file in os.listdir(new_dir):
            orig_name = fr"{new_dir}/{file}"
            image_file = Image.open(orig_name) # open colour image
            image_file = image_file.convert('RGB') # convert image to black and white
            image_file.save(orig_name)
            
#             new_name = fr"{new_dir}/{fname}_{num}.jpg"
#             os.rename(orig_name, new_name)
            num+=1
    num=1

# %%
random.shuffle(animal_types)
animal_types
# Out:
# ['horse',
#  'hyena',
#  'frog',
#  'pig',
#  'monkey',
#  'bee',
#  'birds',
#  'chicken',
#  'duck',
#  'sheep',
#  'dog',
#  'lion',
#  'elephant',
#  'turkey',
#  'bear',
#  'owl',
#  'cat',
#  'cow',
#  'donkey',
#  'tiger',
#  'cricket']

# %%
random.shuffle(animal_types)
animal_types
# Out:
# ['dog',
#  'birds',
#  'chicken',
#  'pig',
#  'cow',
#  'donkey',
#  'bear',
#  'cricket',
#  'owl',
#  'cat',
#  'sheep',
#  'tiger',
#  'turkey',
#  'horse',
#  'hyena',
#  'monkey',
#  'bee',
#  'lion',
#  'duck',
#  'elephant',
#  'frog']

# %%
lis_index = []
for x in range(10):
    lis_index.append(random.randrange(50))
lis_index.sort()
lis_index
# Out:
# [9, 14, 17, 18, 19, 24, 29, 31, 38, 41]
